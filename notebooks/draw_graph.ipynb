# %%
import os, sys
PWD = os.getenv('PWD')
os.chdir(PWD)
sys.path.insert(0, os.getenv('PWD'))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings.py")
import django
django.setup()

# %%
from graphs.models import *
import matplotlib.pyplot as plt
import networkx as nx
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# This is going to plot the result of
#
# ```
# jmeichle@stacy-desktop:~/projects/django_graphs$ python manage.py create_dumb_graph
# DB Models Loaded. Creating a dumb Graph of two nodes linked.
# Creating graph with name=test
# Creating Node with name=FirstNode
# Creating Node with name=SecondNode
# Creating Edge with value=foobar
# Relating Edge=foobar to node=FirstNode
# Relating Edge=foobar to node=SecondNode
# Done.
# ```

# %%
graph_id = 1 # Find them with: python manage.py networkx_ipython -l
nx_graph = Graph.objects.get(id=graph_id).get_networkx_graph()

# write edgelist to grid.edgelist
nx.write_edgelist(nx_graph, path="grid.edgelist", delimiter=":")
# read edgelist from grid.edgelist
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

nx.draw(H, with_labels=True)
plt.show()

# %% [markdown]
# This is going to plot the result of the not so dumb graph:
#
# ```
# jmeichle@stacy-desktop:~/projects/django_graphs$ python manage.py create_less_dumb_graph
# DB Models Loaded. Creating a dumb Graph of two nodes linked.
# Creating graph with name=test
# Creating Node with name=1
# Creating Node with name=2
# Creating Edge with value=e1
# Relating Edge=e1 to node=1
# Relating Edge=e1 to node=2
# Creating Node with name=3
# Creating Node with name=4
# Creating Node with name=5
# Creating Edge with value=e2
# Creating Edge with value=e3
# Relating Edge=e2 to node=3
# Relating Edge=e2 to node=4
# Relating Edge=e3 to node=4
# Relating Edge=e3 to node=5
# Creating Edge with value=e2
# Relating Edge=e4 to node=2
# Relating Edge=e4 to node=4
# Done.
# ```

# %%
graph_id = 2 # Find them with: python manage.py networkx_ipython -l
nx_graph = Graph.objects.get(id=graph_id).get_networkx_graph()

# write edgelist to grid.edgelist
nx.write_edgelist(nx_graph, path="grid.edgelist", delimiter=":")
# read edgelist from grid.edgelist
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

nx.draw(H, with_labels=True)
plt.show()
